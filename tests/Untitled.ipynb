# %%
import test_cli as tc
tc.test_cli()
# Out:
# /bin/sh: line 1: run-analysis: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[3], line 2
#       1 import test_cli as tc
# ----> 2 tc.test_cli()
#
# File /afs/hep.wisc.edu/user/korupolu/zxxhbb/egamma-tnp/tests/test_cli.py:30, in test_cli()
#      29 def test_cli():
# ---> 30     subprocess.run(
#      31         "run-analysis --config tests/example_runner.json --settings tests/example_settings.json --fileset tests/example_fileset.json --binning tests/example_binning.json --output tests/output --executor threads",
#      32         shell=True,
#      33         check=True,
#      34     )
#      36     with open("tests/example_fileset.json") as f:
#      37         fileset = json.load(f)
#
# File /usr/local/lib/python3.12/subprocess.py:573, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     571     retcode = process.poll()
# ...
